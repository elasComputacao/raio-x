# %%
import pandas as pd
import numpy as np

# %%
PATH_TO_CSV = "../../livia_computacao/dados_pre_processados/alunos_computacao.csv"
df_alunos = pd.read_csv(PATH_TO_CSV)

# %%
def generate_id(s):
    return abs(hash(s)) % (10 ** 10)

df_alunos['id'] = df_alunos['matricula'].apply(generate_id)

# %%
df_alunos = df_alunos.drop(["cpf"], axis=1)
# antes de retirar a coluna de matricula eh necessario fazer join com as outras tabelas
#df_alunos = df_alunos.drop(["matricula"], axis=1)

df_alunos
# Out:
#       codigo_curriculo  codigo_ingresso  periodo_ingresso forma_ingresso  \
# 0                 1979                1            1983.1     VESTIBULAR
# 1                 1979                1            1984.1     VESTIBULAR
# 2                 1979                1            1984.1     VESTIBULAR
# 3                 1979                1            1977.2     VESTIBULAR
# 4                 1979                1            1979.2     VESTIBULAR
# ...                ...              ...               ...            ...
# 3951              2017               18            2016.1           SISU
# 3952              2017               18            2016.1           SISU
# 3953              2017               18            2016.1           SISU
# 3954              2017               18            2016.1           SISU
# 3955              2017               18            2016.1           SISU
#
#       codigo_evasao forma_evasao  periodo_evasao  evadiu_periodo forma_saida  \
# 0                 1     GRADUADO          1987.2            10.0    Graduado
# 1                 1     GRADUADO          1988.2            10.0    Graduado
# 2                 1     GRADUADO          1987.2             8.0    Graduado
# 3                 1     GRADUADO          1982.2            11.0    Graduado
# 4                 1     GRADUADO          1985.2            13.0    Graduado
# ...             ...          ...             ...             ...         ...
# 3951              0      REGULAR             0.0             NaN     Regular
# 3952              0      REGULAR             0.0             NaN     Regular
# 3953              0      REGULAR             0.0             NaN     Regular
# 3954              0      REGULAR             0.0             NaN     Regular
# 3955              0      REGULAR             0.0             NaN     Regular
#
#      acao_afirmativa  ...   forma_reserva_vagas       sexo codigo_cor  \
# 0                Não  ...  Sem Reserva De Vagas  Masculino          0
# 1                Não  ...  Sem Reserva De Vagas  Masculino          0
# 2                Não  ...  Sem Reserva De Vagas   Feminino          0
# 3                Não  ...  Sem Reserva De Vagas  Masculino          0
# 4                Não  ...  Sem Reserva De Vagas   Feminino          0
# ...              ...  ...                   ...        ...        ...
# 3951             Não  ...  Sem Reserva De Vagas  Masculino          3
# 3952             Não  ...  Sem Reserva De Vagas  Masculino          1
# 3953             Sim  ...          Escola Renda  Masculino          1
# 3954             Sim  ...      Escola Renda Cor  Masculino          3
# 3955             Não  ...  Sem Reserva De Vagas  Masculino          1
#
#            nome_cor idade_ingresso  idade_evasao  tipo_ensino_medio  \
# 0     Não declarada             18          22.0                NaN
# 1     Não declarada             19          23.0                NaN
# 2     Não declarada              0           0.0                NaN
# 3     Não declarada             23          28.0                NaN
# 4     Não declarada             21          27.0                NaN
# ...             ...            ...           ...                ...
# 3951          Parda             18           NaN                1.0
# 3952         Branca             18           NaN                1.0
# 3953         Branca             20           NaN                2.0
# 3954          Parda             19           NaN                2.0
# 3955         Branca             18           NaN                1.0
#
#                 ensino_medio apv_media_geral         id
# 0              Não informado          581.00  183110305
# 1              Não informado          640.00  184110102
# 2              Não informado          818.00  184110103
# 3              Não informado          538.00  177210160
# 4              Não informado          481.00  179210019
# ...                      ...             ...        ...
# 3951  Somente escola privada          699.48  116110367
# 3952  Somente escola privada          698.02  116110745
# 3953  Somente escola pública          681.34  116110612
# 3954  Somente escola pública          621.88  116110409
# 3955  Somente escola privada          728.80  116110520
#
# [3956 rows x 21 columns]
